# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from time import sleep
import requests
import json
import re
from selenium.common.exceptions import NoSuchElementException
import csv
import pandas as pd
from urllib.request import urlopen
import sys
import io
import glob
import os

# %%
#기존 csv 파일 읽어들이기
path = r'../crawler/1980s'                     # use your path
all_files = glob.glob(os.path.join(path, "*.csv")) 

results = []
attr_names = ['rank', 'sond_id', 'title', 'singers', 'album', 'date','genre', 'creator', 'lyric']


for f in range(len(all_files)):
    if f % 2 == 0:
        count = 0
        with open(str(all_files[f]), newline='') as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                if count < 10:
                    result = {}
                    result['rank'] = row['rank']
                    result['song_id'] = row['song_id']
                    result['title'] = row['title']
                    result['singers'] = row['singers']
                    result['album'] = row['album']
                    result['date'] = row['date']
                    result['genre'] = row['genre']
                    result['creator'] = row['creator']
                    result['lyric'] = row['lyric']    
                    results.append(result)
                    count += 1
                else:
                    break

# %%
print(results)
# Out:
# [{'rank': '1', 'song_id': '1003049', 'title': '못다핀 꽃 한 송이', 'singers': '김수철', 'album': '작은 거인 김수철 (못다핀 꽃 한 송이)', 'date': '1983.08.15', 'genre': 'Rock', 'creator': '김수철', 'lyric': '언제 가셨는데 안오시나 한잎두고 가신님아 가지위에 눈물 적셔놓고 이는 바람소리 남겨놓고 앙상한 가지 위에 그 잎새는 한 잎 달빛마저 구름에 가려 외로움만 더해가네 밤새 새소리에 지쳐버린 한잎마저 떨어지려나 먼곳에 계셨어도 피우리라 못다핀 꽃 한송이 피우리라  언제 가셨는데 안오시나 가시다가 잊으셨나 고운 꽃잎비로 적셔놓고 긴긴 찬바람에 어이하리 앙상한 가지위에 흐느끼는 잎새 꽃한송이 피우려 홀로 안타까워 떨고있나 함께 울어주던 새도 지쳐 어디론가 떠나간뒤 님 떠난 그 자리에 두고두고 못다핀 꽃 한송이 피우리라'}, {'rank': '2', 'song_id': '68155', 'title': '슬픔의 심로', 'singers': '김학래', 'album': '김학래 전집', 'date': '1989', 'genre': 'Ballad', 'creator': '김학래', 'lyric': '낙엽이 외로이 떨어지는 건 두 사람이 헤어지는 건  슬프기 때문에 눈물을 흘려요 두 사람이 흘려요  우린 헤어질수 없기 때문에 창밖에는 비가 내려요  두 사람은 우산도 안 썼네요  헤어지기 마음이 아파 비를 맞아요 고개를 숙여요  우린 둘만이 사랑하기 때문에  이 시간이 지나고 또 지나 햇살이 비추면  온 마음을 열고 나그네가 되어요  뜨거운 마음으로 눈물을 적셔요 슬픔을 적셔요  이젠 뒤 돌아 서서 고개를 들어요    때론 슬픔에 아파 어쩔줄 모르고  이룰 수 없는 순간들을 그렸어요  정다웠고 정다웠던 지난날의 이야기 속에  우리 이제는 떠나야 하나요  이 시간이 지나고 또 지나 햇살이 비추면  온 마음을 열고 나그네가 되어요  뜨거운 마음으로 눈물을 적셔요 슬픔을 적셔요  이젠 뒤 돌아 서서 고개를 들어요  이 시간이 지나고 또 지나 햇살이 비추면  온 마음을 열고 나그네가 되어요  뜨거운 마음으로 눈물을 적셔요 슬픔을 적셔요  이젠 뒤 돌아 서서 고개를 들어요'}, {'rank': '3', 'song_id': '59193', 'title': '친구여', 'singers': '조용필', 'album': '산유화/여자의 정/한강', 'date': '1983.06.25', 'genre': 'Ballad', 'creator': '하지영',
이 내리던 어느날 우리 따스한 기억들 언제까지 내 사랑이여라 내 사랑이여라 거리엔 다정한 연인들 혼자서 걷는 외로운 나 아름다운 사랑 얘기를 잊을 수 있을까 그대 떠난 봄처럼 다시 목련은 피어나고 아픈가슴 빈 자리엔 하얀 목련이 진다  거리엔 다정한 연인들 혼자서 걷는 외로운 나 아름다운 사랑 얘기를 잊을 수 있을까 그대 떠난 봄처럼 다시 목련은 피어나고 아픈 가슴 빈 자리엔 하얀 목련이 진다 아픈 가슴 빈 자리엔 하얀 목련이 진다 아픈 가슴 빈 자리엔 하얀 목련이 진다'}, {'rank': '7', 'song_id': '76684', 'title': '그대가 미워요', 'singers': '전영록', 'album': '사랑은 연필로 쓰세요', 'date': '1983.11.01', 'genre': 'Ballad', 'creator': '송수욱,송주호', 'lyric': '내맘에 새겨있는 그대의 사랑노래는 어린시절 부푼 꿈처럼 가슴에 남아 있어요 어느날 내게 던진 의미없는 한마디에 눈물지며 돌아서버린 그대가 미웠어요 미웠어요 지금 나는 한 마리 파랑새 울음되어 하늘높이 가슴을 당신께 전합니다 보내주오 따스한 옛날의 그 눈망울 들려줘요 목소리 다정스런 그 미소를  빗방울 방울 방울 가득고인 당신의 모습이지만 너무나 빨리 사라져 버려요 비개인 하늘가에 오색의 무지개가 뜨지만 손톱만큼씩 작아져 버려요 내맘에 새겨있는 그대의 사랑노래는 어린시절 부푼 꿈처럼 가슴에 남아 있어요 어느날 내게 던진 의미없는 한마디에 눈물지며 돌아서버린 그대가 미웠어요 미웠어요  빗방울 방울 방울 가득고인 당신의 모습이지만 너무나 빨리 사라져 버려요 비개인 하늘가에 오색의 무지개가 뜨지만 손톱만큼씩 작아져 버려요 내맘에 새겨있는 그대의 사랑노래는 어린시절 부푼 꿈처럼 가슴에 남아 있어요 어느날 내게 던진 의미없는 한마디에 눈물지며 돌아서버린 그대가 미웠어요 미웠어요'}, {'rank': '8', 'song_id': '2780448', 'title': '그대는 나의 인생', 'singers': '한울타리', 'album': '눈물의 승차권/그대는 나 ...

# %%
driver = webdriver.Chrome('./chromedriver')
song_id = results[400]['song_id']
driver.get('https://www.melon.com/song/detail.htm?songId='+song_id)
driver.implicitly_wait(2)

# %%
html = driver.page_source
soup = BeautifulSoup(html, "lxml")

# %%
singer_ids = []
singer_chunk = soup.select('#downloadfrm > div > div > div.entry > div.info > div.artist > a')[0]
singer_id = str(singer_chunk).split('goArtistDetail')[1].split('"')[0].split("'")[1]
singer_ids.append(singer_id)

# %%
singer_search = driver.find_element_by_xpath('//*[@id="downloadfrm"]/div/div/div[2]/div[1]/div[2]/a')
singer_search.click()
driver.implicitly_wait(2)

# %%
detail_page = driver.find_element_by_xpath('//*[@id="conts"]/div[3]/ul/li[2]/a')
detail_page.click()
driver.implicitly_wait(2)

# %%
html = driver.page_source
soup = BeautifulSoup(html, "lxml")
block = soup.select('#conts > div.section_atistinfo03 > dl')[0]
block = str(block).replace('\n','')
block = str(block).replace('\t','')
array = str(block).split('<dt>')

debut_num = 0
type_num = 0
company_num = 0

for a in range(len(array)):
    if '데뷔' in array[a]:
        debut_num = a
    elif '유형' in array[a]:
        type_num = a
    elif '소속사명' in array[a]:
        company_num = a
print(debut_num)


#print(str(block).split('<dt>'))#
# Out:
# 1

# %%
debut = soup.select('#conts > div.section_atistinfo03 > dl > dd:nth-of-type({})'.format(debut_num))[0].text
print(debut)
detail = soup.select('#conts > div.section_atistinfo03 > dl > dd:nth-of-type({})'.format(type_num))[0].text
detail = detail.replace('\n','')
detail = detail.replace('\t','')
print(detail.split('|'))
singer_type = detail[0]
singer_gender = detail[1]

# %%
box = soup.select('#conts > div.section_atistinfo03')[0].text
html = driver.page_source
soup = BeautifulSoup(html, "lxml")

if '소속사명' in box:
    company = soup.select('#conts > div.section_atistinfo03 > dl > dd:nth-of-type({})'.format(company_num)[0].text
    print(company)
# Out:
# yes
# 후크엔터테인먼트

# %%
singer_ids = []

# %%
driver = webdriver.Chrome('./chromedriver')
driver.implicitly_wait(2)
singer_ids = []
song_sings = []
song_ids = []
addtional_results = []

#song id, singer_id, debut, type, gender, company
for result in results:
    print("--------------------start-------------------------")
    song_sing = {}
    song_id = result['song_id']
    
    if song_id in song_ids:
        pass
    else:
        song_ids.append(song_id)

        song_sing['song_id'] = song_id
        print("song_id : " + song_id)
        driver.get('https://www.melon.com/song/detail.htm?songId='+song_id)
        driver.implicitly_wait(5)

        additional_result = {}
        additional_result['song_id'] = song_id

        html = driver.page_source
        soup = BeautifulSoup(html, "lxml")

        #불러오지 않은 정보라면

        singer_chunk = soup.select('#downloadfrm > div > div > div.entry > div.info > div.artist > a')[0]
        singer_id = str(singer_chunk).split('goArtistDetail')[1].split('"')[0].split("'")[1]
        additional_result['singer_id'] = singer_id  
        print("singer_id : " + singer_id)
        song_sing['singer_id'] = singer_id
        song_sings.append(song_sing)


        if singer_id not in singer_ids:
            singer_ids.append(singer_id)
            driver.implicitly_wait(5)
            singer_search = driver.find_element_by_xpath('//*[@id="downloadfrm"]/div/div/div[2]/div[1]/div[2]/a')
            singer_search.click()
            driver.implicitly_wait(2)
            #print("singer_search")
            detail_page = driver.find_element_by_xpath('//*[@id="conts"]/div[3]/ul/li[2]/a')
            detail_page.click()
            
            driver.implicitly_wait(5)
            #print("detail_page")

            html = driver.page_source
            soup = BeautifulSoup(html, "lxml")
            driver.implicitly_wait(2)            
            #데뷔, 타입, 소속사명 있는 블록
            block = soup.select('#conts > div.section_atistinfo03 > dl')[0]
            block = str(block).replace('\n','')
            block = str(block).replace('\t','')
            array = str(block).split('<dt>')

            debut_num = 0
            type_num = 0
            company_num = 0

            for a in range(len(array)):
                if '데뷔' in array[a]:
                    debut_num = a
                elif '유형' in array[a]:
                    type_num = a
                elif '소속사명' in array[a]:
                    company_num = a

            if debut_num != 0:
                debut = soup.select('#conts > div.section_atistinfo03 > dl > dd:nth-of-type({})'.format(debut_num))[0].text
                #print(debut)
                if '|' in debut:
                    debut = debut.split('|')[0].replace('\n','')
                    print("debut : "+debut)
                additional_result['debut'] = debut

            if type_num != 0:
                detail = soup.select('#conts > div.section_atistinfo03 > dl > dd:nth-of-type({})'.format(type_num))[0].text
                detail = detail.replace('\n','')
                detail = detail.replace('\t','')
                detail = detail.split('|')

                singer_type = detail[0]
                singer_gender = detail[1]
                print("singer_type : "+singer_type)
                print("singer_gender : "+singer_gender)

                additional_result['singer_type'] = singer_type
                additional_result['singer_gender'] = singer_gender

            if company_num != 0:
                company = soup.select('#conts > div.section_atistinfo03 > dl > dd:nth-of-type({})'.format(company_num))[0].text
                print("company : "+company)
                additional_result['company'] = company

            addtional_results.append(additional_result)
        else:
            print("이미 가져온 가수 정보")
            pass
# Out:
# --------------------start-------------------------
# song_id : 1003049
# singer_id : 30
# singer_type : 솔로
# singer_gender : 남성
# --------------------start-------------------------
# song_id : 68155
# singer_id : 6
# debut : 1979
# singer_type : 솔로
# singer_gender : 남성
# --------------------start-------------------------
# song_id : 59193
# singer_id : 19
# singer_type : 솔로
# singer_gender : 남성
# company : YPC프로덕션
# --------------------start-------------------------
# song_id : 1867829
# singer_id : 4788
# debut : 1985
# singer_type : 솔로
# singer_gender : 남성
# --------------------start-------------------------
# song_id : 1002443
# singer_id : 990
# debut : 1974
# singer_type : 솔로
# singer_gender : 여성
# company : 제이뮤직컴퍼니
# --------------------start-------------------------
# song_id : 525801
# singer_id : 859
# singer_type : 솔로
# singer_gender : 여성
# --------------------start-------------------------
# song_id : 76684
# singer_id : 23
# singer_type : 솔로
# singer_gender : 남성
# company : R-엔터테인먼트
# --------------------start-------------------------
# song_id : 2780448
# singer_id : 102421
# singer_type : 그룹
# singer_gender : 혼성
# --------------------start-------------------------
# song_id : 1726823
# singer_id : 32
# debut : 1977
# singer_type : 솔로
# singer_gender : 남성
# company : 락코리아
# --------------------start-------------------------
# song_id : 66539
# singer_id : 100751
# debut : 1983
# singer_type : 그룹
# singer_gender : 혼성
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 1005216
# singer_id : 812
# debut : 1978
# singer_type : 솔로
# singer_gender : 남성
# --------------------start-------------------------
# song_id : 1003051
# singer_id : 30
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 76683
# singer_id : 23
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 1314281
# singer_id : 751
# singer_type : 솔로
# singer_gender : 남성
# company : 김창완밴드
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 61379
# singer_id : 1012
# debut : 1978.09
# singer_type : 솔로
# singer_gender : 여성
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 49275
# singer_id : 914
# debut : 1974
# singer_type : 솔로
# singer_gender : 남성
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 1008148
# singer_id : 5023
# debut : 1984.01
# singer_type : 솔로
# singer_gender : 여성
# --------------------start-------------------------
# song_id : 27192
# singer_id : 2020
# debut : 1982
# singer_type : 솔로
# singer_gender : 여성
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 1003052
# singer_id : 30
# --------------------start-------------------------
# song_id : 1314276
# singer_id : 751
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 2216560
# singer_id : 2020
# --------------------start-------------------------
# song_id : 996058
# singer_id : 14065
# singer_type : 솔로
# singer_gender : 남성
# --------------------start-------------------------
# song_id : 2781708
# singer_id : 448
# singer_type : 솔로
# singer_gender : 남성
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 81113
# singer_id : 19
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 1003056
# singer_id : 30
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 526762
# singer_id : 1169
# debut : 1977
# singer_type : 솔로
# singer_gender : 남성
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 170848
# singer_id : 5570
# singer_type : 솔로
# singer_gender : 남성
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 604845
# singer_id : 990
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 2773596
# singer_id : 7697
# debut : 1967
# singer_type : 솔로
# singer_gender : 여성
# --------------------start-------------------------
# song_id : 3618060
# singer_id : 33
# singer_type : 솔로
# singer_gender : 여성
# company : 라이트웨이브 엔터테인먼트
# --------------------start-------------------------
# song_id : 27194
# singer_id : 2020
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 69715
# singer_id : 4826
# debut : 1979
# singer_type : 솔로
# singer_gender : 여성
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 1008364
# singer_id : 29
# debut : 1976
# singer_type : 솔로
# singer_gender : 여성
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 51158
# singer_id : 40
# singer_type : 솔로
# singer_gender : 여성
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 2513212
# singer_id : 102013
# singer_type : 그룹
# singer_gender : 남성
# --------------------start-------------------------
# song_id : 992352
# singer_id : 101012
# singer_type : 그룹
# singer_gender : 남성
# --------------------start-------------------------
# song_id : 1003075
# singer_id : 30
# --------------------start-------------------------
# song_id : 48360
# singer_id : 966
# debut : 1984
# singer_type : 솔로
# singer_gender : 여성
# company : 후크엔터테인먼트
# --------------------start-------------------------
# song_id : 430515
# singer_id : 7684
# debut : 1984
# singer_type : 솔로
# singer_gender : 여성
# --------------------start-------------------------
# song_id : 62770
# singer_id : 5722
# singer_type : 솔로
# singer_gender : 남성
# --------------------start-------------------------
# song_id : 637620
# singer_id : 101971
# debut : 1983.02
# singer_type : 그룹
# singer_gender : 혼성
# --------------------start-------------------------
# song_id : 1002233
# singer_id : 21
# singer_type : 솔로
# singer_gender : 남성
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 91191
# singer_id : 1062
# debut : 1973
# singer_type : 솔로
# singer_gender : 여성
# --------------------start-------------------------
# song_id : 1016285
# singer_id : 1004
# debut : 1983
# singer_type : 솔로
# singer_gender : 남성
# company : 퍼플K
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 1003070
# singer_id : 30
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 314761
# singer_id : 5761
# debut : 1979
# singer_type : 솔로
# singer_gender : 여성
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 48478
# singer_id : 23
# --------------------start-------------------------
# song_id : 48364
# singer_id : 966
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 420274
# singer_id : 13078
# singer_type : 솔로
# singer_gender : 여성
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 1009480
# singer_id : 27
# debut : 1984
# singer_type : 솔로
# singer_gender : 남성
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 48361
# singer_id : 966
# --------------------start-------------------------
# song_id : 54344
# singer_id : 12
# singer_type : 솔로
# singer_gender : 남성
# --------------------start-------------------------
# song_id : 60876
# singer_id : 101013
# singer_type : 그룹
# singer_gender : 남성
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 64899
# singer_id : 990
# --------------------start-------------------------
# song_id : 1003072
# singer_id : 30
# --------------------start-------------------------
# song_id : 2036556
# singer_id : 101012
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 66528
# singer_id : 100751
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 50897
# singer_id : 5856
# singer_type : 솔로
# singer_gender : 남성
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# --------------------start-------------------------
# song_id : 1008373
# singer_id : 29
# --------------------start-------------------------
# song_id : 51971
# singer_id : 6179
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-e4b38e1bb112> in <module>()
#      42             driver.implicitly_wait(5)
#      43             singer_search = driver.find_element_by_xpath('//*[@id="downloadfrm"]/div/div/div[2]/div[1]/div[2]/a')
# ---> 44             singer_search.click()
#      45             driver.implicitly_wait(2)
#      46             #print("singer_search")
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     374         data = utils.dump_json(params)
#     375         url = '%s%s' % (self._url, path)
# --> 376         return self._request(command_info[0], url, body=data)
#     377
#     378     def _request(self, method, url, body=None):
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     397
#     398         if self.keep_alive:
# --> 399             resp = self._conn.request(method, url, body=body, headers=headers)
#     400
#     401             statuscode = resp.status
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      68             return self.request_encode_body(method, url, fields=fields,
#      69                                             headers=headers,
# ---> 70                                             **urlopen_kw)
#      71
#      72     def request_encode_url(self, method, url, fields=None, headers=None,
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     146         extra_kw.update(urlopen_kw)
#     147
# --> 148         return self.urlopen(method, url, **extra_kw)
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     319             response = conn.urlopen(method, url, **kw)
#     320         else:
# --> 321             response = conn.urlopen(method, u.request_uri, **kw)
#     322
#     323         redirect_location = redirect and response.get_redirect_location()
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~/anaconda3/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~/anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%